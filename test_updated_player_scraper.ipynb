# %%
from PlayerScraper import PlayerScraper

# %%
ps = PlayerScraper()

# %%
ps.players_df
# Out:
#                     Player  From    To  Pos    Ht     Wt         Birth Date  \
# 0           Alaa Abdelnaby  1991  1995  F-C  6-10  240.0      June 24, 1968
# 1          Zaid Abdul-Aziz  1969  1978  C-F   6-9  235.0      April 7, 1946
# 2     Kareem Abdul-Jabbar*  1970  1989    C   7-2  225.0     April 16, 1947
# 3       Mahmoud Abdul-Rauf  1991  2001    G   6-1  162.0      March 9, 1969
# 4        Tariq Abdul-Wahad  1998  2003    F   6-6  223.0   November 3, 1974
# ...                    ...   ...   ...  ...   ...    ...                ...
# 4798            Ante Žižić  2018  2020  F-C  6-10  266.0    January 4, 1997
# 4799              Jim Zoet  1983  1983    C   7-1  240.0  December 20, 1953
# 4800             Bill Zopf  1971  1971    G   6-1  170.0       June 7, 1948
# 4801           Ivica Zubac  2017  2020    C   7-0  240.0     March 18, 1997
# 4802            Matt Zunic  1949  1949  G-F   6-3  195.0  December 19, 1919
#
#                       Colleges  \
# 0                         Duke
# 1                   Iowa State
# 2                         UCLA
# 3                          LSU
# 4     Michigan, San Jose State
# ...                        ...
# 4798                       NaN
# 4799     Kent State University
# 4800                  Duquesne
# 4801                       NaN
# 4802         George Washington
#
#                                            Player_links    BBrefID
# 0     https://www.basketball-reference.com/players/a...  abdelal01
# 1     https://www.basketball-reference.com/players/a...  abdulza01
# 2     https://www.basketball-reference.com/players/a...  abdulka01
# 3     https://www.basketball-reference.com/players/a...  abdulma02
# 4     https://www.basketball-reference.com/players/a...  abdulta01
# ...                                                 ...        ...
# 4798  https://www.basketball-reference.com/players/z...  zizican01
# 4799  https://www.basketball-reference.com/players/z...   zoetji01
# 4800  https://www.basketball-reference.com/players/z...   zopfbi01
# 4801  https://www.basketball-reference.com/players/z...  zubaciv01
# 4802  https://www.basketball-reference.com/players/z...  zunicma01
#
# [4803 rows x 10 columns]

# %%
ps.Extract_All_Players()

# %%
ps.player_search('kobe')

# %%
kobe_page_source = ps.extract_page_source()

# %%
ps.extract_all_tables_for_player(kobe_page_source)

# %%
ps.player_search('Michael Jordan')

# %%
mj_page_source = ps.extract_page_source()

# %%
ps.extract_all_tables_for_player(mj_page_source)

# %%
ps.Extract_All_Players()
